# %% [markdown]
# ##Videos for scrapping comments
#
# The videos are selected based on views count
#
#
# 1. https://www.youtube.com/watch?v=VbiRNT_gWUQ&ab_channel=InsiderScience
# 2.https://www.youtube.com/watch?v=yiw6_JakZFc&ab_channel=Kurzgesagt%E2%80%93InaNutshell
# 3.https://www.youtube.com/watch?v=0pJ1oD-OXZo&ab_channel=BLACKPINK
# 4.https://www.youtube.com/watch?v=e6rglsLy1Ys&ab_channel=NationalGeographic
# 5.https://www.youtube.com/watch?v=TZ0j6kr4ZJ0&ab_channel=DWDocumentary

# %% [markdown]
# ## Code to scrape comments using Youtube API

# %%
dev = "AIzaSyB1sW1a5AVxpXTbLjP3mUaqwpo-Scb1OPU"

# %% [markdown]
# #For video 1

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="VbiRNT_gWUQ",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="VbiRNT_gWUQ", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df1 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df1
# Out:
#                     author            updated_at  like_count  \
# 0        @JustACarnotaurus  2023-12-27T22:03:58Z           0
# 1              @QwartzBeat  2023-12-27T19:21:34Z           0
# 2              @QwartzBeat  2023-12-27T18:15:02Z           0
# 3              @QwartzBeat  2023-12-27T18:14:26Z           0
# 4         @draghiceanu2006  2023-12-27T15:28:40Z           0
# ...                    ...                   ...         ...
# 17667  @daviddaugherty2144  2015-03-04T03:45:32Z           0
# 17668    @sensorieskin7367  2015-03-01T20:21:57Z           0
# 17669      @BrandonSLockey  2015-02-26T18:03:44Z           0
# 17670              @rarier  2015-02-26T01:51:39Z           0
# 17671             @bonurb1  2015-02-18T19:35:18Z           0
#
#                                                     text  public
# 0                                    Florida be like:😐🫠🫥    True
# 1      While the question asks about how Earth would ...    True
# ...

# %% [markdown]
# #For video 2

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="yiw6_JakZFc",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="yiw6_JakZFc", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df2
# Out:
#                       author            updated_at  like_count  \
# 0                @kurzgesagt  2021-09-22T12:27:33Z       12586
# 1                 @maple5998  2023-12-26T08:25:23Z           1
# 2               @samlair3342  2023-12-23T17:33:53Z           0
# 3       @InnocentBread-iw3pk  2023-12-22T16:12:53Z           0
# 4      @Dj-Parralax-Aphelion  2023-12-21T12:08:10Z           0
# ...                      ...                   ...         ...
# 35073                @j1o970  2021-09-22T13:59:39Z           0
# 35074     @InfinityGaming420  2021-09-22T13:59:39Z           0
# 35075     @marcorogialli7827  2021-09-22T13:59:38Z           3
# 35076               @Yoel202  2021-09-22T13:59:36Z          72
# 35077            @kurzgesagt  2021-09-22T12:27:33Z       12586
#
#                                                     text  public
# 0      You want to learn more about science? Check ou...    True
# 1      Conclusion : Human Extinction is only way to f...    True
# ...

# %% [markdown]
# #For video 3

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="0pJ1oD-OXZo",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="0pJ1oD-OXZo", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df3 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df3
# Out:
#                           author            updated_at  like_count  \
# 0              @SitiAisyah-kb2ne  2023-12-22T04:14:52Z           0
# 1                     @Iam-li4eu  2023-12-07T15:34:33Z           0
# 2               @user-gr8tg8fr2x  2023-12-04T12:45:12Z           0
# 3                   @iamjosh7290  2023-11-23T19:41:23Z           1
# 4                      @dearines  2023-11-23T09:40:40Z           2
# ...                          ...                   ...         ...
# 35585             @saragomaa4852  2021-11-03T02:00:20Z           2
# 35586  @maicaelissetuvillara7811  2021-11-03T02:00:20Z           1
# 35587           @kristinerobin25  2021-11-03T02:00:20Z           3
# 35588                  @buskosin  2021-11-03T02:00:19Z           4
# 35589              @aungkham3149  2021-11-03T02:00:16Z          14
#
#                                                     text  public
# 0                                         omgg jisoo??😭❤    True
# ...

# %% [markdown]
# #For video 4

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="e6rglsLy1Ys",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="e6rglsLy1Ys", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df4 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df4
# Out:
#                           author            updated_at  like_count  \
# 0                    @Draakie100  2023-12-27T14:09:44Z           0
# 1                  @finaledits11  2023-12-25T12:41:07Z           0
# 2    @RAS_SI_Strategy_Motivation  2023-12-17T13:22:23Z           0
# 3               @user-qp8we3ss9x  2023-12-02T07:43:27Z           0
# 4               @user-mu3iy8fq3d  2023-11-27T08:46:25Z           0
# ..                           ...                   ...         ...
# 711           @ashasshussain7269  2017-10-16T12:10:45Z          25
# 712              @gurjotvirk5257  2017-10-16T12:08:49Z          19
# 713                    @deep4630  2017-10-16T12:08:01Z          32
# 714                 @artgirl1578  2017-10-16T12:04:19Z          13
# 715                 @Kenny-ii1kt  2017-10-16T12:02:26Z           3
#
#                                                   text  public
# 0    In most "1st world" countries we live in a soc...    True
# ...

# %% [markdown]
# #For video 5

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="TZ0j6kr4ZJ0",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="TZ0j6kr4ZJ0", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df5 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df5
# Out:
#                      author            updated_at  like_count  \
# 0           @jiggyquinn5635  2023-12-28T00:58:09Z           0
# 1          @erikpolmann4308  2023-12-20T20:07:41Z           0
# 2            @jojobaker1764  2023-12-19T22:18:16Z           0
# 3           @triplemoon9563  2023-12-19T16:25:41Z           0
# 4               @julieb3808  2023-12-19T04:43:27Z           0
# ...                     ...                   ...         ...
# 6364             @jan-br3pl  2017-11-08T21:23:38Z         392
# 6365         @geroestetumor  2017-11-08T21:12:51Z           9
# 6366  @minutesagoedited9761  2017-11-08T20:41:31Z          39
# 6367            @SDTNionios  2017-11-08T20:14:21Z         137
# 6368  @minutesagoedited9761  2017-11-08T20:13:08Z          13
#
#                                                    text  public
# 0     This is not the first place to be swallowed by...    True
# 1                                                🙏🏽🙏🏽🫶🏽    True
# ...

# %% [markdown]
# #Concating / Merging all the dataframes into 1 single dataframe

# %%
import pandas as pd

#df1, df2, df3, df4, df5 are dataframes

# Using concat to concatenate the dataframes vertically
result_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# ignore_index=True resets the index of the resulting dataframe

# Display the resulting dataframe
print(result_df)
# Out:
#                       author            updated_at  like_count  \
# 0          @JustACarnotaurus  2023-12-27T22:03:58Z           0
# 1                @QwartzBeat  2023-12-27T19:21:34Z           0
# 2                @QwartzBeat  2023-12-27T18:15:02Z           0
# 3                @QwartzBeat  2023-12-27T18:14:26Z           0
# 4           @draghiceanu2006  2023-12-27T15:28:40Z           0
# ...                      ...                   ...         ...
# 95420             @jan-br3pl  2017-11-08T21:23:38Z         392
# 95421         @geroestetumor  2017-11-08T21:12:51Z           9
# 95422  @minutesagoedited9761  2017-11-08T20:41:31Z          39
# 95423            @SDTNionios  2017-11-08T20:14:21Z         137
# 95424  @minutesagoedited9761  2017-11-08T20:13:08Z          13
#
#                                                     text  public
# 0                                    Florida be like:😐🫠🫥    True
# 1      While the question asks about how Earth would ...    True
# ...

# %% [markdown]
# #Dropping Unnecessary columns

# %%
import pandas as pd

# Assuming df is your dataframe and columns_to_drop is a list of column names
columns_to_drop = ['author', 'updated_at', 'like_count','public']

result_df = result_df.drop(columns=columns_to_drop)

# Display the resulting dataframe
print(result_df)
# Out:
#                                                     text
# 0                                    Florida be like:😐🫠🫥
# 1      While the question asks about how Earth would ...
# 2      The Intergovernmental Panel on Climate Change ...
# 3      If all the ice on Earth were to melt, sea leve...
# 4                  Do melted ice cubes over run the cup?
# ...                                                  ...
# 95420  I really enjoyed this video. This is the first...
# 95421  Do you expect me, as a European, to care about...
# 95422  Thing is, even I could design and build a wate...
# 95423  Great! Please do keep uploading such documenta...
# 95424  Grow some MJ. Send to me for $200/oz? lol my p...
#
# [95425 rows x 1 columns]

# %%
result_df
# Out:
#                                                     text
# 0                                    Florida be like:😐🫠🫥
# 1      While the question asks about how Earth would ...
# 2      The Intergovernmental Panel on Climate Change ...
# 3      If all the ice on Earth were to melt, sea leve...
# 4                  Do melted ice cubes over run the cup?
# ...                                                  ...
# 95420  I really enjoyed this video. This is the first...
# 95421  Do you expect me, as a European, to care about...
# 95422  Thing is, even I could design and build a wate...
# 95423  Great! Please do keep uploading such documenta...
# 95424  Grow some MJ. Send to me for $200/oz? lol my p...
#
# [95425 rows x 1 columns]

# %% [markdown]
# #Download the dataset

# %%
from google.colab import files

result_df.to_csv('result_df.csv')
files.download('result_df.csv')
